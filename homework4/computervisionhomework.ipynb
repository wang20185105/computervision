# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

image = cv2.imread("d:\computervision\dsu1.jpg")
im = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# Four corners of the book in source image
pts_src = np.array([[320, 280], [760, 310], [320, 530], [765, 510]])

# Four corners of the book in destination image.
pts_dst = np.array([[320, 280], [760, 280], [320, 530], [760, 530]])

# Calculate Homography
h, status = cv2.findHomography(pts_src, pts_dst)

# Warp source image to destination based on homography
im2 = cv2.warpPerspective(im, h, (im.shape[1], im.shape[0]))

width_in_inches = 15
height_in_inches = 15
dots_per_inch = 70

f = plt.figure(
    figsize=(width_in_inches, height_in_inches),
    dpi=dots_per_inch)

f.add_subplot(1,2, 1)
plt.imshow(im)
plt.axis('off')
f.add_subplot(1,2, 2)
plt.imshow(im2)
plt.axis('off')
plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

image = cv2.imread("d:\computervision\dsu5.jpg")
im = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# Four corners of the book in source image
pts_src = np.array([[580, 335], [755, 375], [580, 485], [760, 500]])

# Four corners of the book in destination image.
pts_dst = np.array([[580, 335], [760, 335], [580, 500], [760, 500]])

# Calculate Homography
h, status = cv2.findHomography(pts_src, pts_dst)

# Warp source image to destination based on homography
im2 = cv2.warpPerspective(im, h, (im.shape[1], im.shape[0]))

width_in_inches = 15
height_in_inches = 15
dots_per_inch = 70

f = plt.figure(
    figsize=(width_in_inches, height_in_inches),
    dpi=dots_per_inch)

f.add_subplot(1,2, 1)
plt.imshow(im)
plt.axis('off')
f.add_subplot(1,2, 2)
plt.imshow(im2)
plt.axis('off')
plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

image = cv2.imread("d:\computervision\dsu7.jpg")
im = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# Four corners of the book in source image
pts_src = np.array([[145, 405], [895, 405], [135,520], [895, 570]])

# Four corners of the book in destination image.
pts_dst = np.array([[145, 405], [895, 405], [145, 520], [895, 520]])

# Calculate Homography
h, status = cv2.findHomography(pts_src, pts_dst)

# Warp source image to destination based on homography
im2 = cv2.warpPerspective(im, h, (im.shape[1], im.shape[0]))

width_in_inches = 15
height_in_inches = 15
dots_per_inch = 70

f = plt.figure(
    figsize=(width_in_inches, height_in_inches),
    dpi=dots_per_inch)

f.add_subplot(1,2, 1)
plt.imshow(im)
plt.axis('off')
f.add_subplot(1,2, 2)
plt.imshow(im2)
plt.axis('off')
plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

image = cv2.imread("d:\computervision\dsu9.jpg")
im = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# Four corners of the book in source image
pts_src = np.array([[260, 195], [715, 210], [265,640], [700, 590]])

# Four corners of the book in destination image.
pts_dst = np.array([[260, 195], [715, 195], [260, 640], [715, 640]])

# Calculate Homography
h, status = cv2.findHomography(pts_src, pts_dst)

# Warp source image to destination based on homography
im2 = cv2.warpPerspective(im, h, (im.shape[1], im.shape[0]))

width_in_inches = 15
height_in_inches = 15
dots_per_inch = 70

f = plt.figure(
    figsize=(width_in_inches, height_in_inches),
    dpi=dots_per_inch)

f.add_subplot(1,2, 1)
plt.imshow(im)
plt.axis('off')
f.add_subplot(1,2, 2)
plt.imshow(im2)
plt.axis('off')
plt.show()
